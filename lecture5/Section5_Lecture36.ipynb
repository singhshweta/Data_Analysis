# %% [markdown]
# ## Subset & Index data

# %%
import numpy as np
import pandas as pd

# %%
# Load the data into a DataFrame
# data of endangered languages
data = pd.read_csv('endangeredLang.csv')
 
data.head(n=5)
# Out:
#      ID Name in English                                          Countries  \
# 0  1022   South Italian                                              Italy
# 1  1023        Sicilian                                              Italy
# 2   383       Low Saxon  Germany, Denmark, Netherlands, Poland, Russian...
# 3   335      Belarusian  Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4   382         Lombard                                 Italy, Switzerland
#
#           Country codes alpha 3 Degree of endangerment  Number of speakers  \
# 0                           ITA             Vulnerable           7500000.0
# 1                           ITA             Vulnerable           5000000.0
# 2       DEU, DNK, NLD, POL, RUS             Vulnerable           4800000.0
# 3  BRB, LVA, LTU, POL, RUS, UKR             Vulnerable           4000000.0
# 4                      ITA, CHE  Definitely endangered           3500000.0
#
# ...

# %%
data[6:] #selecting all entries from index 6 onwards
# Out:
#         ID                             Name in English  \
# 6     2211                            Yiddish (Israel)
# 7     1586                                       Gondi
# 8     1020                        Limburgian-Ripuarian
# 9     1943                 Quechua of Southern Bolivia
# 10    1565                                     Kumaoni
# 11     755                                      Aymara
# 12     349                            Emilian-Romagnol
# 13     399                                 Piedmontese
# 14    1021                                     Venetan
# 15    1985                                      Zazaki
# 16    1591                               Kurux (India)
# 17    2065                                     Tamajeq
# 18    1585                                        Tulu
# 19    1556                                      Kangdi
# 20     410                                       Scots
# 21    1026                                      Torlak
# ...

# %%
data[::2] #select entries at even index locations
# Out:
#         ID                             Name in English  \
# 0     1022                               South Italian
# 2      383                                   Low Saxon
# 4      382                                     Lombard
# 6     2211                            Yiddish (Israel)
# 8     1020                        Limburgian-Ripuarian
# 10    1565                                     Kumaoni
# 12     349                            Emilian-Romagnol
# 14    1021                                     Venetan
# 16    1591                               Kurux (India)
# 18    1585                                        Tulu
# 20     410                                       Scots
# 22    1476                                West Flemish
# 24    1067                                     Chechen
# 26    1227                                     Meithei
# 28    1013                            Quechua of Cuzco
# 30     377                                    Ligurian
# ...

# %%
data.iloc[0:8,0:7] #specify the ranges of rows and columns

#positional indexing
## iloc[row slicing, column slicing]
# Out:
#      ID   Name in English                                          Countries  \
# 0  1022     South Italian                                              Italy
# 1  1023          Sicilian                                              Italy
# 2   383         Low Saxon  Germany, Denmark, Netherlands, Poland, Russian...
# 3   335        Belarusian  Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4   382           Lombard                                 Italy, Switzerland
# 5   405            Romani  Albania, Germany, Austria, Belarus, Bosnia and...
# 6  2211  Yiddish (Israel)                                             Israel
# 7  1586             Gondi                                              India
#
#                                Country codes alpha 3 Degree of endangerment  \
# 0                                                ITA             Vulnerable
# 1                                                ITA             Vulnerable
# ...

# %%
# select all columns for rows of index values 0 and 10
data.loc[[0, 10], :]
# Out:
#       ID Name in English     Countries Country codes alpha 3  \
# 0   1022   South Italian         Italy                   ITA
# 10  1565         Kumaoni  India, Nepal              IND, NPL
#
#    Degree of endangerment  Number of speakers  Latitude  Longitude  \
# 0              Vulnerable           7500000.0   40.9798    15.2490
# 10             Vulnerable           2003783.0   29.4778    79.8486
#
#                           Description of the location
# 0   Campania, Lucania (Basilicata), Abruzzi (Abruz...
# 10  Uttarakhand, also in Uttar Pradesh, Madhya Pra...

# %%
#select specified columns of specified rows
data.loc[4:8,['Countries','Name in English']]
# Out:
#                                            Countries       Name in English
# 4                                 Italy, Switzerland               Lombard
# 5  Albania, Germany, Austria, Belarus, Bosnia and...                Romani
# 6                                             Israel      Yiddish (Israel)
# 7                                              India                 Gondi
# 8                      Germany, Belgium, Netherlands  Limburgian-Ripuarian

# %%
#isolate rows and columns
data[['Countries','Name in English']][4:8]
# Out:
#                                            Countries   Name in English
# 4                                 Italy, Switzerland           Lombard
# 5  Albania, Germany, Austria, Belarus, Bosnia and...            Romani
# 6                                             Israel  Yiddish (Israel)
# 7                                              India             Gondi

# %%
data[data.Countries == "Italy"] #isolate by row names
# Out:
#         ID    Name in English Countries Country codes alpha 3  \
# 0     1022      South Italian     Italy                   ITA
# 1     1023           Sicilian     Italy                   ITA
# 13     399        Piedmontese     Italy                   ITA
# 36     337        Campidanese     Italy                   ITA
# 53     353           Friulian     Italy                   ITA
# 80     381         Logudorese     Italy                   ITA
# 157    408          Sassarese     Italy                   ITA
# 170    356          Gallurese     Italy                   ITA
# 197   1347           Arbëresh     Italy                   ITA
# 212   1330     Gallo-Sicilian     Italy                   ITA
# 320    565              Ladin     Italy                   ITA
# 391   1614    Griko (Salento)     Italy                   ITA
# 510   1343  Algherese Catalan     Italy                   ITA
# 729   1349    Molise Croatian     Italy                   ITA
# ...

# %%
x=data.loc[data.Countries.isin(['Italy','Nepal'])] #isolate by two row labels

# %%
x.head(15)
# Out:
#        ID Name in English Countries Country codes alpha 3  \
# 0    1022   South Italian     Italy                   ITA
# 1    1023        Sicilian     Italy                   ITA
# 13    399     Piedmontese     Italy                   ITA
# 36    337     Campidanese     Italy                   ITA
# 39   1117           Newar     Nepal                   NPL
# 53    353        Friulian     Italy                   ITA
# 65   1118           Magar     Nepal                   NPL
# 80    381      Logudorese     Italy                   ITA
# 84    964         Bantawa     Nepal                   NPL
# 88   1113          Gurung     Nepal                   NPL
# 157   408       Sassarese     Italy                   ITA
# 170   356       Gallurese     Italy                   ITA
# 197  1347        Arbëresh     Italy                   ITA
# 212  1330  Gallo-Sicilian     Italy                   ITA
# 259  1025        Chamling     Nepal                   NPL
#
# ...

# %%
df = data[:]
df.rename(columns ='Degree of endangerment' : 'DegreeofEndangerment'},inplace = True)
df[(df['Countries'] == "India") & (df['DegreeofEndangerment'] == "Vulnerable")]
# Out:
#         ID Name in English Countries Country codes alpha 3  \
# 7     1586           Gondi     India                   IND
# 16    1591   Kurux (India)     India                   IND
# 18    1585            Tulu     India                   IND
# 26    1227         Meithei     India                   IND
# 33    1577             Kui     India                   IND
# 34    1231           Khasi     India                   IND
# 35    1229            Bodo     India                   IND
# 44    1211         Mundari     India                   IND
# 58    1230            Mizo     India                   IND
# 72    1165           Karbi     India                   IND
# 76    1212              Ho     India                   IND
# 102   1563        Garhwali     India                   IND
# 107   1205            Sora     India                   IND
# 108   1119          Konyak     India                   IND
# 109   1130              Ao     India                   IND
# ...

# %%
df=data[:] #make a copy of the data frame stored in data

# %%
df.rename(columns={'Number of speakers':'NumberofSpeakers'}, inplace=True) #replace "Number of Speakers" with "Number"

# %%
df.head(5)
# Out:
#      ID Name in English                                          Countries  \
# 0  1022   South Italian                                              Italy
# 1  1023        Sicilian                                              Italy
# 2   383       Low Saxon  Germany, Denmark, Netherlands, Poland, Russian...
# 3   335      Belarusian  Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4   382         Lombard                                 Italy, Switzerland
#
#           Country codes alpha 3 Degree of endangerment  NumberofSpeakers  \
# 0                           ITA             Vulnerable         7500000.0
# 1                           ITA             Vulnerable         5000000.0
# 2       DEU, DNK, NLD, POL, RUS             Vulnerable         4800000.0
# 3  BRB, LVA, LTU, POL, RUS, UKR             Vulnerable         4000000.0
# 4                      ITA, CHE  Definitely endangered         3500000.0
#
#    Latitude  Longitude                        Description of the location
# ...

# %%
df[(df.Countries == "India") | (df.NumberofSpeakers<100)] #specify 2 conditions to be fulfilled
# Out:
#         ID  Name in English                           Countries  \
# 7     1586            Gondi                               India
# 16    1591    Kurux (India)                               India
# 18    1585             Tulu                               India
# 19    1556           Kangdi                               India
# 26    1227          Meithei                               India
# 33    1577              Kui                               India
# 34    1231            Khasi                               India
# 35    1229             Bodo                               India
# 44    1211          Mundari                               India
# 52    1559         Mandeali                               India
# 56    1091           Mising                               India
# 58    1230             Mizo                               India
# 64    1558          Mahasui                               India
# 72    1165            Karbi                               India
# ...
